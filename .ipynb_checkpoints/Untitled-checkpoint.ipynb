# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import glob
import cv2
import os
train = ImageDataGenerator(rescale= 1/255)
validation = ImageDataGenerator(rescale= 1/255)

train_dataset = train.flow_from_directory('basedata/train',
                                          target_size= (200,200),
                                          batch_size= 3,
                                          class_mode= 'binary')
validation_dataset = train.flow_from_directory('basedata/validation',
                                          target_size= (200,200),
                                          batch_size= 3,
                                          class_mode= 'binary')

train_dataset.class_indices
train_dataset.classes

model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape=(200,200,3)),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                    #
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu',input_shape=(200,200,3)),
                                    ##
                                    tf.keras.layers.Flatten(),
                                    ##
                                    tf.keras.layers.Dense(512,activation= 'relu'),
                                    ##
                                    ##
                                    tf.keras.layers.Dense(1,activation= 'sigmoid')
]
)
model.compile(loss= 'binary_crossentropy',
              optimizer =RMSprop(lr=0.001),
              metrics=['accuracy']
              )
model_fit = model.fit(train_dataset,
                      steps_per_epoch= 3,
                      epochs= 10,
                      validation_data= validation_dataset
                      )
dir_path = 'basedata/test'
label = []
for p in os.listdir(dir_path):
    for each in os.listdir(os.path.join(dir_path,p)):
        img = image.load_img(dir_path + "/"+ p + '/' + each)
        plt.imshow(img)
        plt.show()
        X = image.img_to_array(img)
        X = np.expand_dims(X,axis=0)
        

    
            #img = image.load_img(dir_path + '/' + im)
            #plt.imshow(img)
            #plt.show()
            #X = image.img_to_array(img)
            #X = np.expand_dims(X,axis=0)
            #images = np.vstack([X])
            #val = model.predict()
# Out:
# Found 30 images belonging to 2 classes.
# Found 30 images belonging to 2 classes.
# Epoch 1/10
# 3/3 [==============================] - 5s 1s/step - loss: 30.6132 - accuracy: 0.2083 - val_loss: 1.0992 - val_accuracy: 0.4333
# Epoch 2/10
# 3/3 [==============================] - 2s 831ms/step - loss: 0.6495 - accuracy: 0.9028 - val_loss: 1.4550 - val_accuracy: 0.6000
# Epoch 3/10
# 3/3 [==============================] - 2s 899ms/step - loss: 0.4403 - accuracy: 0.8889 - val_loss: 0.5613 - val_accuracy: 0.7000
# Epoch 4/10
# 3/3 [==============================] - 3s 904ms/step - loss: 0.7864 - accuracy: 0.6111 - val_loss: 4.5975 - val_accuracy: 0.4333
# Epoch 5/10
# 3/3 [==============================] - 2s 835ms/step - loss: 2.2586 - accuracy: 0.6528 - val_loss: 0.5968 - val_accuracy: 0.6333
# Epoch 6/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.5268 - accuracy: 0.8472 - val_loss: 0.5589 - val_accuracy: 0.6333
# Epoch 7/10
# ...

# %%
dir_path = 'basedata/test'
label = []
for p in os.listdir(dir_path):
    for each in os.listdir(os.path.join(dir_path,p)):
        img = image.load_img(dir_path + "/"+ p + '/' + each)
        plt.imshow(img)
        plt.show()
        X = image.img_to_array(img)
        X = np.expand_dims(X,axis=0)
        images = np.vstack([X])
        #label.append(p)
        val = model.predict(images)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 200, 200, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 200, 200, 3), dtype=tf.float32, name='conv2d_6_input'), name='conv2d_6_input', description="created by layer 'conv2d_6_input'"), but it was called on an input with incompatible shape (None, 183, 275, 3).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-d5e3fd605ce4> in <module>
#      10         images = np.vstack([X])
#      11         #label.append(p)
# ---> 12         val = model.predict(images)
#      13
#      14
#
# ~/anaconda3/envs/my_env_py3npm/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
# ...
